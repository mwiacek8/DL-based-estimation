# %%
import numpy as np
import math
import pandas as pd

from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = [15, 5]
plt.rc('legend',fontsize=15)

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Convolution2D, MaxPooling2D, Flatten , Activation
from tensorflow.keras import optimizers
from keras.utils.vis_utils import plot_model

# %%
import pickle

# %%
import scipy
from scipy.stats import rv_histogram

import seaborn as sns

# %% [markdown]
# ### Functions - common for each notebook

# %%
from basic_functions import trajectory, trajectory_intervals, generate_nn_input, check_distribution, plot_distribution

# %% [markdown]
# ### Functions - modified for each case

# %%
def trajectories(T, n, k, Wiener=None):
  
    h = float(T/n)
    h_sqrt = np.sqrt(h)
    # values_in_T = []
    X_real = []
    X_approx = []
    T_ = []
  
    for j in range(k):
        
        X_real_temp = x_0
        X_approx_temp = x_0

        x_real = [X_real_temp]
        x_approx = [X_approx_temp]

        t_temp = 0.0
        t = [t_temp]
        
        for i in range(1, n+1):

            if Wiener is not None:
                dW = Wiener[i-1]

            else:
                dW = np.random.normal(0, h_sqrt)

            X_r = X_real_temp + a(t_temp, X_real_temp)*h + b_real(t_temp, X_real_temp)*dW
            x_real.append(X_r)  

            X_a = X_approx_temp + a(t_temp, X_approx_temp)*h + sigma_[i]*dW
            x_approx.append(X_a)  

            t_temp = i*h
            t.append(t_temp)

            X_real_temp = X_r
            X_approx_temp = X_a

        X_real.append(x_real)
        X_approx.append(x_approx)


        T_.append(t)

        if (len(np.array(X_real).flatten()) != len(np.array(X_approx).flatten())):
            print("Trajectories have different length")
      
    return np.array(T_).flatten(), np.array(X_real).flatten(), np.array(X_approx).flatten()

# %%
def trajectories_intervals(T, n, k, Wiener=None):
  
    h = float(T/n)
    h_sqrt = np.sqrt(h)
    # values_in_T = []
    X_real = []
    X_approx = []
    
    X_approx_lower_ = []
    X_approx_upper_ = []
    
    
    T_ = []
  
    for j in range(k):
        
        X_real_temp = x_0
        X_approx_temp = x_0

        x_real = [X_real_temp]
        x_approx = [X_approx_temp]
        x_approx_lower = [X_approx_temp]
        x_approx_upper = [X_approx_temp]

        t_temp = 0.0
        t = [t_temp]
        
        for i in range(1, n+1):

            if Wiener is not None:
                dW = Wiener[i-1]

            else:
                dW = np.random.normal(0, h_sqrt)

            X_r = X_real_temp + a(t_temp, X_real_temp)*h + b_real(t_temp, X_real_temp)*dW
            x_real.append(X_r)  

            X_a = X_approx_temp + a(t_temp, X_approx_temp)*h + sigma_[i]*dW
            x_approx.append(X_a)  


            X_a_lower = X_approx_temp + a(t_temp, X_approx_temp) * h - 2 * np.abs(sigma_[i]) * np.sqrt(h)
            X_a_upper = X_approx_temp + a(t_temp, X_approx_temp) * h + 2 * np.abs(sigma_[i]) * np.sqrt(h)
            x_approx_lower.append(X_a_lower)  
            x_approx_upper.append(X_a_upper)  


            t_temp = i*h
            t.append(t_temp)

            X_real_temp = X_r
            X_approx_temp = X_a

        X_real.append(x_real)
        X_approx.append(x_approx)
        X_approx_lower_.append(x_approx_lower)
        X_approx_upper_.append(x_approx_upper)


        T_.append(t)

        if (len(np.array(X_real).flatten()) != len(np.array(X_approx).flatten())):
            print("Trajectories have different length")
      
    return np.array(T_).flatten(), np.array(X_real).flatten(), np.array(X_approx).flatten(), np.array(X_approx_lower_).flatten(), np.array(X_approx_upper_).flatten()

# %% [markdown]
# ### Step 1. Define an equation

# %%
def kappa(t):
    return 2.0

def mu(t):
    return 0.5

def sigma(t):
    return 2*t+0.4+1.5*np.sin(t*4)

# %%
def a(t, x):
    return kappa(t)*(mu(t)-x)

def b(t, x):
    return sigma(t)

# %%
x_0 = 1.0

# %%
equation = [x_0, a, b]

# %% [markdown]
# ### Step 2. Simulation

# %%
# time
T = 2.0

# number of points
n = 10000

# number of trajectories
k = 1

# %%
# set the Wiener process

h = float(T/n)
h_sqrt = np.sqrt(h)

wiener_process = [np.random.normal(0, h_sqrt) for i in range(n)]

# file = open('wiener_process_example_01', 'rb')
# wiener_process = pickle.load(file)
# file.close()

# %%
t_values, x_values = trajectory(T, n, k, equation, wiener_process)

# %%
t_values, x_values, x_low, x_up = trajectory_intervals(T, n, k, equation, wiener_process)

# %%
plt.plot(t_values, x_values, label='X(t)')
plt.legend()
plt.show()

plt.plot(t_values, a(t_values,x_values), label='a(t,x)')
plt.legend()
plt.show()

plt.plot(t_values, b(t_values,x_values), label='b(t,x)')
plt.legend()
plt.show()

# %%
k = 1000

t = t_values[:k]
x1=x_values[:k]
x2=x_low[:k]
x3=x_up[:k]

plt.figure(figsize=(20,10))
plt.plot(t, x1, label='X(t)', linewidth=1)
plt.plot(t, x2, label='X_low(t)', color='grey', linewidth=0.3)
plt.plot(t, x3, label='X_up(t)', color='grey', linewidth=0.3)

plt.fill_between(t_values[:1000], x2, x3, color='lightgrey',alpha=0.5)


plt.legend()
plt.show()

# %% [markdown]
# ### Step 3. Estimate chosen parameter using neural network

# %% [markdown]
# #### 3.1 Loss function

# %%
def b_(t, x, sigma):
    return sigma

# %%
# define loss function that corresponds to NLL (Negative Log Likelihood)
# h - global variable, as also  coefficients a ,b, 
# x_0,x_1,...x_n, y_true = [x_0,x_1,...x_n], delta_y_true = [x_1-x_0,x_2-x_1,...x_n-x_{n-1}]


def SDE_params_loss(y_true,y_pred):

    sigma=tf.math.exp(tf.slice(y_pred,[0,0],[-1,1]))
    x_diff = tf.slice(y_true,[0,2],[-1,1])
    h = tf.slice(y_true,[0,3],[-1,1])

    x = tf.slice(y_true,[0,1],[-1,1])
    t = tf.slice(y_true,[0,0],[-1,1])

    A = tf.math.log(2*math.pi*h*tf.square((b_(t,x,sigma))))
    B = tf.square(x_diff - a_(t,x)*h) / (2*h * tf.square(b_(t,x,sigma)))
    loss = tf.reduce_sum(A/2.0+B,axis=0)

    return loss

# %% [markdown]
# #### 3.2 Neural network model

# %%
x_data, y_data = generate_nn_input(t_values, x_values)

# %%
model =  Sequential()
model.add(Dense(20, activation='sigmoid',batch_input_shape=(None, 1)))
model.add(Dense(50, activation='sigmoid'))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1, activation='linear'))

model.compile(loss=SDE_params_loss,
              optimizer=optimizers.Adam(learning_rate=0.005),
              metrics=[SDE_params_loss])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                40
#
#  dense_1 (Dense)             (None, 50)                1050
#
#  dense_2 (Dense)             (None, 30)                1530
#
#  dense_3 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 2,651
# Trainable params: 2,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model_01_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# #### 3.3 Training

# %%
def a_(t, x):
    return kappa(t)*(mu(t)-x)

# %%
history=model.fit(x_data, y_data, 
                  batch_size=64, 
                  epochs=1000,
                  verbose=1
                 )
# Out:
# Epoch 1/1000
# 157/157 [==============================] - 1s 2ms/step - loss: -84.8978 - SDE_params_loss: -84.6227
# Epoch 2/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -112.3857 - SDE_params_loss: -111.9423
# Epoch 3/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -112.9606 - SDE_params_loss: -112.5664
# Epoch 4/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -115.6477 - SDE_params_loss: -115.2449
# Epoch 5/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -119.1184 - SDE_params_loss: -118.6989
# Epoch 6/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -120.3866 - SDE_params_loss: -119.9700
# Epoch 7/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -120.9978 - SDE_params_loss: -120.5801
# Epoch 8/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -121.5973 - SDE_params_loss: -121.1809
# Epoch 9/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -122.2211 - SDE_params_loss: -121.7565
# Epoch 10/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -122.4891 - SDE_params_loss: -122.0693
# Epoch 11/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -122.8389 - SDE_params_loss: -122.3983
# Epoch 12/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -123.2492 - SDE_params_loss: -122.7898
# Epoch 13/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -123.3553 - SDE_params_loss: -122.9305
# Epoch 14/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -123.4986 - SDE_params_loss: -123.0499
# Epoch 15/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -123.9550 - SDE_params_loss: -123.5336
# Epoch 16/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -124.0313 - SDE_params_loss: -123.5781
# Epoch 17/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -124.4585 - SDE_params_loss: -124.0239
# Epoch 18/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -124.6010 - SDE_params_loss: -124.1696
# Epoch 19/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -124.7840 - SDE_params_loss: -124.3329A: 0s - loss: -125.2131 - SDE_params_loss: -125.
# Epoch 20/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -124.9032 - SDE_params_loss: -124.4477
# Epoch 21/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -125.2374 - SDE_params_loss: -124.7270
# Epoch 22/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -125.3871 - SDE_params_loss: -124.9379
# Epoch 23/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -125.5667 - SDE_params_loss: -125.0938
# Epoch 24/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -125.9405 - SDE_params_loss: -125.4752
# Epoch 25/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -125.9891 - SDE_params_loss: -125.5264
# Epoch 26/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -126.5968 - SDE_params_loss: -126.1545
# Epoch 27/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -127.4571 - SDE_params_loss: -127.0140
# Epoch 28/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -127.6461 - SDE_params_loss: -127.1950
# Epoch 29/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -127.8699 - SDE_params_loss: -127.4139
# Epoch 30/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.5563 - SDE_params_loss: -128.0081
# Epoch 31/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.2874 - SDE_params_loss: -127.8213
# Epoch 32/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.3871 - SDE_params_loss: -127.9092
# Epoch 33/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.5661 - SDE_params_loss: -128.0750
# Epoch 34/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.5130 - SDE_params_loss: -128.0507
# Epoch 35/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.2588 - SDE_params_loss: -127.8201
# Epoch 36/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.3893 - SDE_params_loss: -127.9485
# Epoch 37/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.6633 - SDE_params_loss: -128.1973
# Epoch 38/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.6749 - SDE_params_loss: -128.2060
# Epoch 39/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7204 - SDE_params_loss: -128.2684
# Epoch 40/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8469 - SDE_params_loss: -128.3230
# Epoch 41/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.6642 - SDE_params_loss: -128.1728
# Epoch 42/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8623 - SDE_params_loss: -128.3820
# Epoch 43/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.6051 - SDE_params_loss: -128.1366
# Epoch 44/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8972 - SDE_params_loss: -128.4131
# Epoch 45/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.5069 - SDE_params_loss: -128.0042
# Epoch 46/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8735 - SDE_params_loss: -128.4009
# Epoch 47/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7795 - SDE_params_loss: -128.3303
# Epoch 48/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.6775 - SDE_params_loss: -128.2236
# Epoch 49/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8063 - SDE_params_loss: -128.3210
# Epoch 50/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8170 - SDE_params_loss: -128.3640
# Epoch 51/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8854 - SDE_params_loss: -128.4007
# Epoch 52/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7249 - SDE_params_loss: -128.2699
# Epoch 53/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7533 - SDE_params_loss: -128.2874
# Epoch 54/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7373 - SDE_params_loss: -128.2817
# Epoch 55/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.6982 - SDE_params_loss: -128.2513
# Epoch 56/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7608 - SDE_params_loss: -128.2968
# Epoch 57/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7422 - SDE_params_loss: -128.2961
# Epoch 58/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8992 - SDE_params_loss: -128.4365
# Epoch 59/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9123 - SDE_params_loss: -128.4401
# Epoch 60/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7159 - SDE_params_loss: -128.2713
# Epoch 61/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9267 - SDE_params_loss: -128.4465
# Epoch 62/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7091 - SDE_params_loss: -128.2727
# Epoch 63/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.6962 - SDE_params_loss: -128.2523
# Epoch 64/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9030 - SDE_params_loss: -128.4366
# Epoch 65/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8985 - SDE_params_loss: -128.4163
# Epoch 66/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8935 - SDE_params_loss: -128.4365
# Epoch 67/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8545 - SDE_params_loss: -128.3941
# Epoch 68/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7731 - SDE_params_loss: -128.3207
# Epoch 69/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8347 - SDE_params_loss: -128.3408
# Epoch 70/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7583 - SDE_params_loss: -128.3020
# Epoch 71/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9543 - SDE_params_loss: -128.5040
# Epoch 72/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8837 - SDE_params_loss: -128.4281
# Epoch 73/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7962 - SDE_params_loss: -128.3475
# Epoch 74/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9661 - SDE_params_loss: -128.4884
# Epoch 75/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7644 - SDE_params_loss: -128.3107
# Epoch 76/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9185 - SDE_params_loss: -128.4645
# Epoch 77/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7503 - SDE_params_loss: -128.2731
# Epoch 78/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8675 - SDE_params_loss: -128.4115
# Epoch 79/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8706 - SDE_params_loss: -128.4143
# Epoch 80/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8221 - SDE_params_loss: -128.3760
# Epoch 81/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8110 - SDE_params_loss: -128.3584
# Epoch 82/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7971 - SDE_params_loss: -128.3511
# Epoch 83/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.6173 - SDE_params_loss: -128.1312
# Epoch 84/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.6805 - SDE_params_loss: -128.2393
# Epoch 85/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9037 - SDE_params_loss: -128.4409
# Epoch 86/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8958 - SDE_params_loss: -128.4570
# Epoch 87/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8628 - SDE_params_loss: -128.3965
# Epoch 88/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8688 - SDE_params_loss: -128.4103
# Epoch 89/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8368 - SDE_params_loss: -128.3693
# Epoch 90/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9445 - SDE_params_loss: -128.4617
# Epoch 91/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8369 - SDE_params_loss: -128.3739
# Epoch 92/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8217 - SDE_params_loss: -128.3443
# Epoch 93/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7060 - SDE_params_loss: -128.2321
# Epoch 94/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8938 - SDE_params_loss: -128.4241
# Epoch 95/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9965 - SDE_params_loss: -128.5298
# Epoch 96/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9384 - SDE_params_loss: -128.4555
# Epoch 97/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7121 - SDE_params_loss: -128.2512
# Epoch 98/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9443 - SDE_params_loss: -128.4666
# Epoch 99/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9658 - SDE_params_loss: -128.5011
# Epoch 100/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9071 - SDE_params_loss: -128.4275
# Epoch 101/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8379 - SDE_params_loss: -128.3559
# Epoch 102/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8789 - SDE_params_loss: -128.4378
# Epoch 103/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8987 - SDE_params_loss: -128.4255
# Epoch 104/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8490 - SDE_params_loss: -128.3975
# Epoch 105/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8053 - SDE_params_loss: -128.3473
# Epoch 106/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8234 - SDE_params_loss: -128.3653
# Epoch 107/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0016 - SDE_params_loss: -128.5369
# Epoch 108/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8838 - SDE_params_loss: -128.4186
# Epoch 109/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9336 - SDE_params_loss: -128.4722
# Epoch 110/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9633 - SDE_params_loss: -128.4729
# Epoch 111/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8949 - SDE_params_loss: -128.4242
# Epoch 112/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9333 - SDE_params_loss: -128.4896
# Epoch 113/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9192 - SDE_params_loss: -128.4563
# Epoch 114/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8949 - SDE_params_loss: -128.4549
# Epoch 115/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9175 - SDE_params_loss: -128.4409
# Epoch 116/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9099 - SDE_params_loss: -128.4707
# Epoch 117/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9504 - SDE_params_loss: -128.5095
# Epoch 118/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8752 - SDE_params_loss: -128.4394
# Epoch 119/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7722 - SDE_params_loss: -128.3297
# Epoch 120/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8912 - SDE_params_loss: -128.4410
# Epoch 121/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9116 - SDE_params_loss: -128.4624
# Epoch 122/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9399 - SDE_params_loss: -128.4846
# Epoch 123/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7743 - SDE_params_loss: -128.3030
# Epoch 124/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9343 - SDE_params_loss: -128.4697
# Epoch 125/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9276 - SDE_params_loss: -128.4441
# Epoch 126/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.7849 - SDE_params_loss: -128.3254
# Epoch 127/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9939 - SDE_params_loss: -128.5278
# Epoch 128/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9625 - SDE_params_loss: -128.5036
# Epoch 129/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.7613 - SDE_params_loss: -128.2953A: 0s - loss: -128.2906 - SDE_params_loss: -128.
# Epoch 130/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.8996 - SDE_params_loss: -128.4587
# Epoch 131/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.7889 - SDE_params_loss: -128.3445
# Epoch 132/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0190 - SDE_params_loss: -128.5558
# Epoch 133/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9315 - SDE_params_loss: -128.4623
# Epoch 134/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9305 - SDE_params_loss: -128.4724
# Epoch 135/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9204 - SDE_params_loss: -128.4483
# Epoch 136/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9672 - SDE_params_loss: -128.5046
# Epoch 137/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8890 - SDE_params_loss: -128.4396
# Epoch 138/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9619 - SDE_params_loss: -128.4839
# Epoch 139/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9704 - SDE_params_loss: -128.4999
# Epoch 140/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9486 - SDE_params_loss: -128.4816
# Epoch 141/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8553 - SDE_params_loss: -128.4061
# Epoch 142/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9515 - SDE_params_loss: -128.4840
# Epoch 143/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8794 - SDE_params_loss: -128.4262
# Epoch 144/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9284 - SDE_params_loss: -128.4876
# Epoch 145/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9948 - SDE_params_loss: -128.5243
# Epoch 146/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9082 - SDE_params_loss: -128.4479
# Epoch 147/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9457 - SDE_params_loss: -128.5190
# Epoch 148/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0031 - SDE_params_loss: -128.5074
# Epoch 149/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9738 - SDE_params_loss: -128.4826
# Epoch 150/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9173 - SDE_params_loss: -128.4673
# Epoch 151/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9974 - SDE_params_loss: -128.5124
# Epoch 152/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9285 - SDE_params_loss: -128.4856
# Epoch 153/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9772 - SDE_params_loss: -128.4552
# Epoch 154/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9261 - SDE_params_loss: -128.4374
# Epoch 155/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9277 - SDE_params_loss: -128.4600
# Epoch 156/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9841 - SDE_params_loss: -128.5112
# Epoch 157/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8616 - SDE_params_loss: -128.3951
# Epoch 158/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9226 - SDE_params_loss: -128.4906
# Epoch 159/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8796 - SDE_params_loss: -128.3936
# Epoch 160/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0014 - SDE_params_loss: -128.5190
# Epoch 161/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8756 - SDE_params_loss: -128.4082
# Epoch 162/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0372 - SDE_params_loss: -128.5689
# Epoch 163/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9861 - SDE_params_loss: -128.5163
# Epoch 164/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9418 - SDE_params_loss: -128.4865A: 0s - loss: -129.0616 - SDE_params_loss: -129.06
# Epoch 165/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0416 - SDE_params_loss: -128.5816
# Epoch 166/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9213 - SDE_params_loss: -128.4820
# Epoch 167/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8793 - SDE_params_loss: -128.4381
# Epoch 168/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8916 - SDE_params_loss: -128.4346
# Epoch 169/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9437 - SDE_params_loss: -128.5140
# Epoch 170/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9951 - SDE_params_loss: -128.5428
# Epoch 171/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9655 - SDE_params_loss: -128.4898
# Epoch 172/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0197 - SDE_params_loss: -128.5363
# Epoch 173/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9732 - SDE_params_loss: -128.5092
# Epoch 174/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0941 - SDE_params_loss: -128.6180
# Epoch 175/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9604 - SDE_params_loss: -128.5023
# Epoch 176/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9474 - SDE_params_loss: -128.4996
# Epoch 177/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9906 - SDE_params_loss: -128.5291
# Epoch 178/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0414 - SDE_params_loss: -128.5534
# Epoch 179/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9095 - SDE_params_loss: -128.4435
# Epoch 180/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9847 - SDE_params_loss: -128.5162
# Epoch 181/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9218 - SDE_params_loss: -128.4791
# Epoch 182/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9368 - SDE_params_loss: -128.4818
# Epoch 183/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9536 - SDE_params_loss: -128.5159
# Epoch 184/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9512 - SDE_params_loss: -128.4869
# Epoch 185/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9553 - SDE_params_loss: -128.5107
# Epoch 186/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0691 - SDE_params_loss: -128.5418
# Epoch 187/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9859 - SDE_params_loss: -128.5158
# Epoch 188/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9962 - SDE_params_loss: -128.5282
# Epoch 189/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9119 - SDE_params_loss: -128.4571
# Epoch 190/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9897 - SDE_params_loss: -128.5042
# Epoch 191/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9684 - SDE_params_loss: -128.4914
# Epoch 192/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9774 - SDE_params_loss: -128.5308
# Epoch 193/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0411 - SDE_params_loss: -128.5595
# Epoch 194/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0475 - SDE_params_loss: -128.5621
# Epoch 195/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0607 - SDE_params_loss: -128.5586
# Epoch 196/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9655 - SDE_params_loss: -128.4860
# Epoch 197/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9310 - SDE_params_loss: -128.4670
# Epoch 198/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9861 - SDE_params_loss: -128.5365
# Epoch 199/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0547 - SDE_params_loss: -128.5928
# Epoch 200/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0508 - SDE_params_loss: -128.6051
# Epoch 201/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1242 - SDE_params_loss: -128.6567
# Epoch 202/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9772 - SDE_params_loss: -128.5195
# Epoch 203/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9644 - SDE_params_loss: -128.4809
# Epoch 204/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9700 - SDE_params_loss: -128.5140
# Epoch 205/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0089 - SDE_params_loss: -128.5460
# Epoch 206/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9051 - SDE_params_loss: -128.4566
# Epoch 207/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0079 - SDE_params_loss: -128.5525
# Epoch 208/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0310 - SDE_params_loss: -128.5587
# Epoch 209/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0213 - SDE_params_loss: -128.4950
# Epoch 210/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0774 - SDE_params_loss: -128.5318
# Epoch 211/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9030 - SDE_params_loss: -128.4453
# Epoch 212/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0008 - SDE_params_loss: -128.5322
# Epoch 213/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9681 - SDE_params_loss: -128.5125
# Epoch 214/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9719 - SDE_params_loss: -128.5333
# Epoch 215/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0045 - SDE_params_loss: -128.5483
# Epoch 216/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9660 - SDE_params_loss: -128.4934
# Epoch 217/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8441 - SDE_params_loss: -128.3564A: 0s - loss: -128.9569 - SDE_params_loss: -128.956
# Epoch 218/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0053 - SDE_params_loss: -128.5483
# Epoch 219/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9250 - SDE_params_loss: -128.4313
# Epoch 220/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9893 - SDE_params_loss: -128.4973
# Epoch 221/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0419 - SDE_params_loss: -128.5760
# Epoch 222/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0006 - SDE_params_loss: -128.5418
# Epoch 223/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0091 - SDE_params_loss: -128.5569
# Epoch 224/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9185 - SDE_params_loss: -128.4755
# Epoch 225/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0302 - SDE_params_loss: -128.5570
# Epoch 226/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9679 - SDE_params_loss: -128.5333
# Epoch 227/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0024 - SDE_params_loss: -128.5169
# Epoch 228/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0157 - SDE_params_loss: -128.5652
# Epoch 229/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9787 - SDE_params_loss: -128.5089
# Epoch 230/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0300 - SDE_params_loss: -128.5576
# Epoch 231/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9766 - SDE_params_loss: -128.5336
# Epoch 232/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0472 - SDE_params_loss: -128.5834
# Epoch 233/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9933 - SDE_params_loss: -128.5188
# Epoch 234/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9657 - SDE_params_loss: -128.5318
# Epoch 235/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9112 - SDE_params_loss: -128.4643
# Epoch 236/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9252 - SDE_params_loss: -128.5033
# Epoch 237/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0284 - SDE_params_loss: -128.5839
# Epoch 238/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0399 - SDE_params_loss: -128.5666
# Epoch 239/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0503 - SDE_params_loss: -128.5825
# Epoch 240/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0405 - SDE_params_loss: -128.5850
# Epoch 241/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9955 - SDE_params_loss: -128.5552
# Epoch 242/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0759 - SDE_params_loss: -128.5920
# Epoch 243/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8981 - SDE_params_loss: -128.4537
# Epoch 244/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0282 - SDE_params_loss: -128.5518
# Epoch 245/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0210 - SDE_params_loss: -128.5806
# Epoch 246/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9755 - SDE_params_loss: -128.4818
# Epoch 247/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0710 - SDE_params_loss: -128.5850
# Epoch 248/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9785 - SDE_params_loss: -128.5263
# Epoch 249/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9441 - SDE_params_loss: -128.5034
# Epoch 250/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9617 - SDE_params_loss: -128.4906A: 0s - loss: -128.7873 - SDE_params_loss: -128
# Epoch 251/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9799 - SDE_params_loss: -128.5008
# Epoch 252/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0158 - SDE_params_loss: -128.5602
# Epoch 253/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0534 - SDE_params_loss: -128.5912
# Epoch 254/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0210 - SDE_params_loss: -128.5468
# Epoch 255/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0345 - SDE_params_loss: -128.5590A: 0s - loss: -128.0704 - SDE_params_loss: -128
# Epoch 256/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0436 - SDE_params_loss: -128.5813
# Epoch 257/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9208 - SDE_params_loss: -128.4431
# Epoch 258/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9918 - SDE_params_loss: -128.5495
# Epoch 259/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0890 - SDE_params_loss: -128.6288
# Epoch 260/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9997 - SDE_params_loss: -128.5323
# Epoch 261/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0164 - SDE_params_loss: -128.5410
# Epoch 262/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0724 - SDE_params_loss: -128.6113
# Epoch 263/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9032 - SDE_params_loss: -128.4651
# Epoch 264/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9286 - SDE_params_loss: -128.4782
# Epoch 265/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9775 - SDE_params_loss: -128.5369
# Epoch 266/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0370 - SDE_params_loss: -128.5588
# Epoch 267/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1119 - SDE_params_loss: -128.6120
# Epoch 268/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9787 - SDE_params_loss: -128.4998
# Epoch 269/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9825 - SDE_params_loss: -128.5404
# Epoch 270/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9637 - SDE_params_loss: -128.4992
# Epoch 271/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9919 - SDE_params_loss: -128.5560
# Epoch 272/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9936 - SDE_params_loss: -128.5688
# Epoch 273/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0343 - SDE_params_loss: -128.5543
# Epoch 274/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0280 - SDE_params_loss: -128.5539
# Epoch 275/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0131 - SDE_params_loss: -128.5569
# Epoch 276/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0489 - SDE_params_loss: -128.5966
# Epoch 277/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0617 - SDE_params_loss: -128.5737
# Epoch 278/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9642 - SDE_params_loss: -128.4995
# Epoch 279/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9966 - SDE_params_loss: -128.5499
# Epoch 280/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0205 - SDE_params_loss: -128.5634
# Epoch 281/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0641 - SDE_params_loss: -128.6045
# Epoch 282/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0162 - SDE_params_loss: -128.5403
# Epoch 283/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.8739 - SDE_params_loss: -128.4299
# Epoch 284/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0149 - SDE_params_loss: -128.5467
# Epoch 285/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9968 - SDE_params_loss: -128.5284
# Epoch 286/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0639 - SDE_params_loss: -128.6009
# Epoch 287/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9605 - SDE_params_loss: -128.5295
# Epoch 288/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9929 - SDE_params_loss: -128.5513
# Epoch 289/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9938 - SDE_params_loss: -128.5384
# Epoch 290/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0227 - SDE_params_loss: -128.5494
# Epoch 291/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9692 - SDE_params_loss: -128.5029
# Epoch 292/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0139 - SDE_params_loss: -128.5539
# Epoch 293/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0467 - SDE_params_loss: -128.5972
# Epoch 294/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0377 - SDE_params_loss: -128.5666
# Epoch 295/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0084 - SDE_params_loss: -128.5529
# Epoch 296/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0398 - SDE_params_loss: -128.5835
# Epoch 297/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9991 - SDE_params_loss: -128.5338
# Epoch 298/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0253 - SDE_params_loss: -128.5380
# Epoch 299/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0272 - SDE_params_loss: -128.5904
# Epoch 300/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0536 - SDE_params_loss: -128.5875
# Epoch 301/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9645 - SDE_params_loss: -128.4938
# Epoch 302/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0042 - SDE_params_loss: -128.5699
# Epoch 303/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9784 - SDE_params_loss: -128.5271
# Epoch 304/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0683 - SDE_params_loss: -128.5989
# Epoch 305/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0519 - SDE_params_loss: -128.6076
# Epoch 306/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0395 - SDE_params_loss: -128.5870
# Epoch 307/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9066 - SDE_params_loss: -128.4539
# Epoch 308/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0474 - SDE_params_loss: -128.5837
# Epoch 309/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0478 - SDE_params_loss: -128.5909
# Epoch 310/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9969 - SDE_params_loss: -128.5592
# Epoch 311/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0465 - SDE_params_loss: -128.5855
# Epoch 312/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0241 - SDE_params_loss: -128.5534
# Epoch 313/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.1237 - SDE_params_loss: -128.5982
# Epoch 314/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0449 - SDE_params_loss: -128.6041
# Epoch 315/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0067 - SDE_params_loss: -128.5441
# Epoch 316/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0188 - SDE_params_loss: -128.5498
# Epoch 317/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0354 - SDE_params_loss: -128.5477
# Epoch 318/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0158 - SDE_params_loss: -128.5460
# Epoch 319/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9636 - SDE_params_loss: -128.4986
# Epoch 320/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0140 - SDE_params_loss: -128.5484
# Epoch 321/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9028 - SDE_params_loss: -128.4559
# Epoch 322/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9450 - SDE_params_loss: -128.4830
# Epoch 323/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0521 - SDE_params_loss: -128.5804
# Epoch 324/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0619 - SDE_params_loss: -128.5775
# Epoch 325/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0811 - SDE_params_loss: -128.5909
# Epoch 326/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0813 - SDE_params_loss: -128.6157
# Epoch 327/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0271 - SDE_params_loss: -128.5955
# Epoch 328/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0366 - SDE_params_loss: -128.5450
# Epoch 329/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9971 - SDE_params_loss: -128.5394
# Epoch 330/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0304 - SDE_params_loss: -128.5709
# Epoch 331/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0122 - SDE_params_loss: -128.5488
# Epoch 332/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0401 - SDE_params_loss: -128.5750
# Epoch 333/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9904 - SDE_params_loss: -128.5442
# Epoch 334/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0227 - SDE_params_loss: -128.5374
# Epoch 335/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0103 - SDE_params_loss: -128.5358
# Epoch 336/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0205 - SDE_params_loss: -128.5882
# Epoch 337/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0539 - SDE_params_loss: -128.5612
# Epoch 338/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0580 - SDE_params_loss: -128.5893
# Epoch 339/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -128.9451 - SDE_params_loss: -128.5009
# Epoch 340/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0317 - SDE_params_loss: -128.5685
# Epoch 341/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0386 - SDE_params_loss: -128.5746
# Epoch 342/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0634 - SDE_params_loss: -128.5734
# Epoch 343/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0587 - SDE_params_loss: -128.5945
# Epoch 344/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9716 - SDE_params_loss: -128.5022
# Epoch 345/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0197 - SDE_params_loss: -128.5804
# Epoch 346/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0125 - SDE_params_loss: -128.5608
# Epoch 347/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0262 - SDE_params_loss: -128.5600
# Epoch 348/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0284 - SDE_params_loss: -128.5814
# Epoch 349/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0396 - SDE_params_loss: -128.5497
# Epoch 350/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0704 - SDE_params_loss: -128.6047
# Epoch 351/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0496 - SDE_params_loss: -128.5766
# Epoch 352/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1231 - SDE_params_loss: -128.6241
# Epoch 353/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0819 - SDE_params_loss: -128.6173
# Epoch 354/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0502 - SDE_params_loss: -128.5686
# Epoch 355/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0701 - SDE_params_loss: -128.5970
# Epoch 356/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0010 - SDE_params_loss: -128.5695
# Epoch 357/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0162 - SDE_params_loss: -128.5654
# Epoch 358/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9849 - SDE_params_loss: -128.5095
# Epoch 359/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9894 - SDE_params_loss: -128.5364
# Epoch 360/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9878 - SDE_params_loss: -128.5369
# Epoch 361/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0536 - SDE_params_loss: -128.5959
# Epoch 362/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0178 - SDE_params_loss: -128.5628
# Epoch 363/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0510 - SDE_params_loss: -128.5932
# Epoch 364/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0257 - SDE_params_loss: -128.5446
# Epoch 365/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0334 - SDE_params_loss: -128.5260
# Epoch 366/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.1129 - SDE_params_loss: -128.6546
# Epoch 367/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0686 - SDE_params_loss: -128.5957
# Epoch 368/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0059 - SDE_params_loss: -128.5367
# Epoch 369/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0282 - SDE_params_loss: -128.5682
# Epoch 370/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0637 - SDE_params_loss: -128.6034
# Epoch 371/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0732 - SDE_params_loss: -128.6170
# Epoch 372/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0309 - SDE_params_loss: -128.5964
# Epoch 373/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0063 - SDE_params_loss: -128.5406
# Epoch 374/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9643 - SDE_params_loss: -128.5119
# Epoch 375/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0444 - SDE_params_loss: -128.5963
# Epoch 376/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0130 - SDE_params_loss: -128.5479
# Epoch 377/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0472 - SDE_params_loss: -128.5835
# Epoch 378/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0198 - SDE_params_loss: -128.5567
# Epoch 379/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1168 - SDE_params_loss: -128.6286
# Epoch 380/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0252 - SDE_params_loss: -128.5777
# Epoch 381/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0082 - SDE_params_loss: -128.5569
# Epoch 382/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0688 - SDE_params_loss: -128.5910
# Epoch 383/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0563 - SDE_params_loss: -128.5979
# Epoch 384/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0284 - SDE_params_loss: -128.5734
# Epoch 385/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0206 - SDE_params_loss: -128.5668A: 0s - loss: -129.4795 - SDE_params_loss: -129
# Epoch 386/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0349 - SDE_params_loss: -128.5674
# Epoch 387/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0520 - SDE_params_loss: -128.6062
# Epoch 388/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0154 - SDE_params_loss: -128.5598
# Epoch 389/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0701 - SDE_params_loss: -128.5790
# Epoch 390/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9486 - SDE_params_loss: -128.5158A: 0s - loss: -128.4309 - SDE_params_loss: -128
# Epoch 391/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0288 - SDE_params_loss: -128.5734
# Epoch 392/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0305 - SDE_params_loss: -128.5465
# Epoch 393/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9804 - SDE_params_loss: -128.5258
# Epoch 394/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0389 - SDE_params_loss: -128.5812
# Epoch 395/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0269 - SDE_params_loss: -128.5365
# Epoch 396/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0694 - SDE_params_loss: -128.6342
# Epoch 397/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0382 - SDE_params_loss: -128.5966
# Epoch 398/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0569 - SDE_params_loss: -128.6070
# Epoch 399/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0533 - SDE_params_loss: -128.5927
# Epoch 400/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0929 - SDE_params_loss: -128.6176
# Epoch 401/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0613 - SDE_params_loss: -128.5951
# Epoch 402/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0533 - SDE_params_loss: -128.5801
# Epoch 403/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0461 - SDE_params_loss: -128.5788
# Epoch 404/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -128.9961 - SDE_params_loss: -128.5483
# Epoch 405/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0417 - SDE_params_loss: -128.5724
# Epoch 406/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0553 - SDE_params_loss: -128.5959
# Epoch 407/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0157 - SDE_params_loss: -128.5535
# Epoch 408/1000
# ...
# Epoch 866/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0779 - SDE_params_loss: -128.6187
# Epoch 867/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0441 - SDE_params_loss: -128.5999A: 0s - loss: -129.2085 - SDE_params_loss: -129.208
# Epoch 868/1000
# 157/157 [==============================] - 1s 3ms/step - loss: -129.0896 - SDE_params_loss: -128.6218
# Epoch 869/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.0694 - SDE_params_loss: -128.6142
# Epoch 870/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0697 - SDE_params_loss: -128.6337
# Epoch 871/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1416 - SDE_params_loss: -128.6604
# Epoch 872/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0211 - SDE_params_loss: -128.5753
# Epoch 873/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0691 - SDE_params_loss: -128.6210
# Epoch 874/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1434 - SDE_params_loss: -128.6506
# Epoch 875/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1178 - SDE_params_loss: -128.6583
# Epoch 876/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0992 - SDE_params_loss: -128.6261
# Epoch 877/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0699 - SDE_params_loss: -128.6147
# Epoch 878/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1133 - SDE_params_loss: -128.6649
# Epoch 879/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0875 - SDE_params_loss: -128.6457
# Epoch 880/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0806 - SDE_params_loss: -128.6199
# Epoch 881/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0932 - SDE_params_loss: -128.6510
# Epoch 882/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1173 - SDE_params_loss: -128.6600
# Epoch 883/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1230 - SDE_params_loss: -128.6711
# Epoch 884/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0976 - SDE_params_loss: -128.6291
# Epoch 885/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0907 - SDE_params_loss: -128.6180
# Epoch 886/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0947 - SDE_params_loss: -128.6471
# Epoch 887/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0589 - SDE_params_loss: -128.6072
# Epoch 888/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0831 - SDE_params_loss: -128.6139
# Epoch 889/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0459 - SDE_params_loss: -128.6039
# Epoch 890/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0578 - SDE_params_loss: -128.6149
# Epoch 891/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0883 - SDE_params_loss: -128.6296
# Epoch 892/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1266 - SDE_params_loss: -128.6676
# Epoch 893/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1118 - SDE_params_loss: -128.6342
# Epoch 894/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1114 - SDE_params_loss: -128.6449
# Epoch 895/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0780 - SDE_params_loss: -128.5946
# Epoch 896/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0595 - SDE_params_loss: -128.5968
# Epoch 897/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1029 - SDE_params_loss: -128.6373
# Epoch 898/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1212 - SDE_params_loss: -128.6481
# Epoch 899/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1071 - SDE_params_loss: -128.6349
# Epoch 900/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1216 - SDE_params_loss: -128.6483
# Epoch 901/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0318 - SDE_params_loss: -128.5860
# Epoch 902/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0930 - SDE_params_loss: -128.6124
# Epoch 903/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0747 - SDE_params_loss: -128.5972
# Epoch 904/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1067 - SDE_params_loss: -128.6569
# Epoch 905/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0454 - SDE_params_loss: -128.6000
# Epoch 906/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0863 - SDE_params_loss: -128.6496
# Epoch 907/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0828 - SDE_params_loss: -128.6180
# Epoch 908/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1066 - SDE_params_loss: -128.6456
# Epoch 909/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1216 - SDE_params_loss: -128.6502
# Epoch 910/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0820 - SDE_params_loss: -128.6289
# Epoch 911/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0247 - SDE_params_loss: -128.5792
# Epoch 912/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0323 - SDE_params_loss: -128.5614
# Epoch 913/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0320 - SDE_params_loss: -128.6000
# Epoch 914/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0578 - SDE_params_loss: -128.6062
# Epoch 915/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1043 - SDE_params_loss: -128.6313
# Epoch 916/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0400 - SDE_params_loss: -128.5904
# Epoch 917/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0985 - SDE_params_loss: -128.6347
# Epoch 918/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1393 - SDE_params_loss: -128.6282
# Epoch 919/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0897 - SDE_params_loss: -128.6177
# Epoch 920/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1362 - SDE_params_loss: -128.6777
# Epoch 921/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0653 - SDE_params_loss: -128.5930
# Epoch 922/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0325 - SDE_params_loss: -128.5957
# Epoch 923/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0412 - SDE_params_loss: -128.5788
# Epoch 924/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0781 - SDE_params_loss: -128.6177
# Epoch 925/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.1040 - SDE_params_loss: -128.6500
# Epoch 926/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0892 - SDE_params_loss: -128.6388
# Epoch 927/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0348 - SDE_params_loss: -128.5834
# Epoch 928/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.1052 - SDE_params_loss: -128.6316
# Epoch 929/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.1201 - SDE_params_loss: -128.6369
# Epoch 930/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0828 - SDE_params_loss: -128.6189
# Epoch 931/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0522 - SDE_params_loss: -128.6007
# Epoch 932/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0771 - SDE_params_loss: -128.6226
# Epoch 933/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0802 - SDE_params_loss: -128.6130
# Epoch 934/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1433 - SDE_params_loss: -128.6646
# Epoch 935/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0667 - SDE_params_loss: -128.6158
# Epoch 936/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0611 - SDE_params_loss: -128.5964
# Epoch 937/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0980 - SDE_params_loss: -128.6353
# Epoch 938/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0756 - SDE_params_loss: -128.6091
# Epoch 939/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0784 - SDE_params_loss: -128.6283
# Epoch 940/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0297 - SDE_params_loss: -128.5749
# Epoch 941/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1248 - SDE_params_loss: -128.6442
# Epoch 942/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0823 - SDE_params_loss: -128.6591
# Epoch 943/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1190 - SDE_params_loss: -128.6498
# Epoch 944/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1118 - SDE_params_loss: -128.6753
# Epoch 945/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0577 - SDE_params_loss: -128.5915
# Epoch 946/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0558 - SDE_params_loss: -128.5772
# Epoch 947/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0703 - SDE_params_loss: -128.6513
# Epoch 948/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0580 - SDE_params_loss: -128.5999
# Epoch 949/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0574 - SDE_params_loss: -128.6130
# Epoch 950/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1324 - SDE_params_loss: -128.6551
# Epoch 951/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1161 - SDE_params_loss: -128.6433
# Epoch 952/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1005 - SDE_params_loss: -128.6135
# Epoch 953/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0653 - SDE_params_loss: -128.6155
# Epoch 954/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1114 - SDE_params_loss: -128.6669
# Epoch 955/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1232 - SDE_params_loss: -128.6246
# Epoch 956/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1199 - SDE_params_loss: -128.6651
# Epoch 957/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0710 - SDE_params_loss: -128.6348
# Epoch 958/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0950 - SDE_params_loss: -128.6216
# Epoch 959/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1200 - SDE_params_loss: -128.6595
# Epoch 960/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0659 - SDE_params_loss: -128.6070
# Epoch 961/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0522 - SDE_params_loss: -128.5921
# Epoch 962/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1295 - SDE_params_loss: -128.6674
# Epoch 963/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0246 - SDE_params_loss: -128.5614
# Epoch 964/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0722 - SDE_params_loss: -128.6127
# Epoch 965/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1146 - SDE_params_loss: -128.6312
# Epoch 966/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0434 - SDE_params_loss: -128.5974
# Epoch 967/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1243 - SDE_params_loss: -128.6445A: 0s - loss: -129.3803 - SDE_params_loss: -12
# Epoch 968/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0810 - SDE_params_loss: -128.6456
# Epoch 969/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1172 - SDE_params_loss: -128.6488
# Epoch 970/1000
# 157/157 [==============================] - 0s 3ms/step - loss: -129.1348 - SDE_params_loss: -128.6527
# Epoch 971/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1244 - SDE_params_loss: -128.6563
# Epoch 972/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1131 - SDE_params_loss: -128.6455
# Epoch 973/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0872 - SDE_params_loss: -128.6176
# Epoch 974/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1621 - SDE_params_loss: -128.6877
# Epoch 975/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1072 - SDE_params_loss: -128.6295
# Epoch 976/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0492 - SDE_params_loss: -128.6118
# Epoch 977/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1075 - SDE_params_loss: -128.6457
# Epoch 978/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0926 - SDE_params_loss: -128.6492
# Epoch 979/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0996 - SDE_params_loss: -128.6329A: 0s - loss: -130.1048 - SDE_params_loss: -13
# Epoch 980/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0887 - SDE_params_loss: -128.6285
# Epoch 981/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1013 - SDE_params_loss: -128.6219
# Epoch 982/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1066 - SDE_params_loss: -128.6411
# Epoch 983/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0736 - SDE_params_loss: -128.5970
# Epoch 984/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0895 - SDE_params_loss: -128.6339
# Epoch 985/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1292 - SDE_params_loss: -128.6796
# Epoch 986/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0971 - SDE_params_loss: -128.6444
# Epoch 987/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0865 - SDE_params_loss: -128.6241
# Epoch 988/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1045 - SDE_params_loss: -128.6433
# Epoch 989/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0874 - SDE_params_loss: -128.6176
# Epoch 990/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0756 - SDE_params_loss: -128.6147
# Epoch 991/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1031 - SDE_params_loss: -128.6608
# Epoch 992/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0774 - SDE_params_loss: -128.6246
# Epoch 993/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0942 - SDE_params_loss: -128.6274
# Epoch 994/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1557 - SDE_params_loss: -128.6737
# Epoch 995/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1039 - SDE_params_loss: -128.6316
# Epoch 996/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0781 - SDE_params_loss: -128.6167
# Epoch 997/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0692 - SDE_params_loss: -128.6234
# Epoch 998/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1053 - SDE_params_loss: -128.6400
# Epoch 999/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.1361 - SDE_params_loss: -128.6484
# Epoch 1000/1000
# 157/157 [==============================] - 0s 2ms/step - loss: -129.0706 - SDE_params_loss: -128.6013

# %%
result = model.predict(t_values)
sigma_ = tf.math.exp(result[:,0])

file = open('sigma_example_01', 'wb')
pickle.dump(sigma_, file)
file.close()

# %% [markdown]
# ### Step 4. Evaluation of the results

# %% [markdown]
# #### 4.1 Results from neural network

# %%
file = open('sigma_example_01', 'rb')
sigma_ = pickle.load(file)
file.close()

plt.plot(t_values, x_values, label='X(t)')
plt.legend()
plt.show()

plt.plot(t_values, sigma(t_values), label='real sigma')
plt.plot(t_values, sigma_, label='approx sigma')
plt.legend()

# plt.savefig("example_01_sigma.png")
# plt.show()

# %%
# plot training history

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['SDE_params_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# #### 4.2 Trajectories of both processes with prediction intervals

# %%
def b_real(t, x):
    return sigma(t)

# %%
def b_approx(t):
    return sigma_

# %%
t_values, x_real_values, x_approx_values = trajectories(T,n,1,wiener_process)

fig = plt.figure(figsize=(15,5))
plt.plot(t_values, x_real_values, label='with real sigma')
plt.plot(t_values, x_approx_values, label='with approx sigma')
plt.legend()

plt.savefig("example_01_trajectory.png")
plt.show()

# %%
t_values, x_real_values, x_approx_values, x_approx_low_values, x_approx_up_values = trajectories_intervals(T,n,1,wiener_process)

# %%
k = n

t = t_values[:k]
x1=x_real_values[:k]
x2=x_approx_values[:k]
x3=x_approx_low_values[:k]
x4=x_approx_up_values[:k]

plt.figure(figsize=(20,10))
plt.plot(t, x1, label='with real sigma', linewidth=1)
plt.plot(t, x2, label='with approx sigma', linewidth=1)
plt.plot(t, x3, label='X_low(t)', color='grey', linewidth=0.3)
plt.plot(t, x4, label='X_up(t)', color='grey', linewidth=0.3)

plt.fill_between(t, x3, x4, color='lightgrey',alpha=0.5)

plt.legend()
plt.show()

# %%
k = 500

t = t_values[n-k:]
x1=x_real_values[n-k:]
x2=x_approx_values[n-k:]
x3=x_approx_low_values[n-k:]
x4=x_approx_up_values[n-k:]

plt.figure(figsize=(20,10))
plt.plot(t, x1, label='with real sigma', linewidth=1)
plt.plot(t, x2, label='with approx sigma', linewidth=1)
plt.plot(t, x3, label='X_low(t)', color='grey', linewidth=0.3)
plt.plot(t, x4, label='X_up(t)', color='grey', linewidth=0.3)

plt.fill_between(t, x3, x4, color='lightgrey',alpha=0.5)

# plt.scatter(x=t, y=tempdf["expected_col"], color="red")

plt.legend()
plt.show()

# %%
k = 500

t = t_values[:k]
x1=x_real_values[:k]
x2=x_approx_values[:k]
x3=x_approx_low_values[:k]
x4=x_approx_up_values[:k]

plt.figure(figsize=(20,10))
plt.plot(t, x1, label='with real sigma', linewidth=1)
plt.plot(t, x2, label='with approx sigma', linewidth=1)
plt.plot(t, x3, label='X_low(t)', color='grey', linewidth=0.3)
plt.plot(t, x4, label='X_up(t)', color='grey', linewidth=0.3)

plt.fill_between(t, x3, x4, color='lightgrey',alpha=0.5)

plt.legend()
plt.show()

# %% [markdown]
# #### 4.3 Simulate many trajectories to see both distributions

# %%
n_traj = 100

# %%
X_tab, X_approx_tab = check_distribution(T, n, n_traj, trajectories)

# %%
plot_distribution(X_tab, X_approx_tab)
# Out:
# Mean value for real:  0.29184445180496865
# Mean value for approx:  0.28133897595107554
# Standard deviation for real:  2.1485551569426797
# Standard deviation for approx:  2.2585686642293967

# %%
def exp_val_approx(X, X_approx):
    return sum(np.square(np.abs(np.subtract(X,X_approx))))/len(X)

# %%
exp_val_approx(X_tab, X_approx_tab)
# Out:
# 0.012909163027360608

# %%
np.sqrt(exp_val_approx(X_tab, X_approx_tab))
# Out:
# 0.11361849773413046

# %%
# SAVE DATA AS PICKLE

result_tab = np.array([X_tab, X_approx_tab])

file = open('01_results_100', 'wb')
pickle.dump(result_tab, file)
file.close()

# %%
# OPEN IF NEEDED

file = open('01_results_100', 'rb')
data = pickle.load(file)
file.close()

X_test = data[0]
X_approx_test = data[1]

# %% [markdown]
# #### Results for 1000 trajectories

# %%
# OPEN IF NEEDED

file = open('01_results_1000_6_02', 'rb')
data = pickle.load(file)
file.close()

X_tab = data[0]
X_approx_tab = data[1]

# %%
plot_distribution(X_tab, X_approx_tab)
# Out:
# Mean value for real:  0.5145487288894467
# Mean value for approx:  0.5153059245445766
# Standard deviation for real:  2.4561915730221893
# Standard deviation for approx:  2.38838905288853

# %%
def exp_val_approx(X, X_approx):
    return sum(np.square(np.abs(np.subtract(X,X_approx))))/len(X)

# %%
exp_val_approx(X_tab, X_approx_tab)
# Out:
# 0.00661141442127585

# %%
np.sqrt(exp_val_approx(X_tab, X_approx_tab))
# Out:
# 0.08131060460527796

# %% [markdown]
# #### 4.4 Check our Theorem 1

# %%
# theta_1 
theta_approx = sigma_

# %%
# theta_2 
t_values = np.linspace(0,T,n+1)
theta_real = sigma(t_values)

# %%
# LEFT SIDE
np.sqrt(exp_val_approx(X_tab, X_approx_tab))
# Out:
# 0.11361849773413046

# %%
# RIGHT SIDE
2*np.abs(theta_approx - theta_real).max()
# Out:
# 0.6396932601928711

# %% [markdown]
# #### 4.5 Check Kolmogorov-Smirnov (KS) test

# %%
scipy.stats.ks_2samp(X_tab, X_approx_tab)
# Out:
# KstestResult(statistic=0.04, pvalue=0.999998821968263)

# %% [markdown]
# #### 4.6 QQ plot

# %%
df_pct = pd.DataFrame()
df_pct['q_X'] = np.percentile(X_tab, range(100))
df_pct['q_X_approx'] = np.percentile(X_approx_tab, range(100))

# %%
plt.scatter(x='q_X', y='q_X_approx', data=df_pct, label='Actual fit');
sns.lineplot(x='q_X', y='q_X', data=df_pct, color='r', label='Line of perfect fit');
plt.xlabel('Quantile of X')
plt.ylabel('Quantile of X_approx')
plt.legend()
plt.title("QQ plot");
plt.savefig("example_01_qq-plot.png")
